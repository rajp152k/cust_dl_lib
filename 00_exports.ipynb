# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os 
os.chdir("/content/drive/My Drive/fast.ai v3/section 2/cust_dl_lib")

# !git config --global user.email "rajp152000@gmail.com"
# !git config --global user.name "rajp152k"

# %% [markdown]
# BEGIN

# %%
#export 
TEST = 'test'

# %% [markdown]
# creating a testing framework in run_notebook.py<br>
# - will show any exceptions that occur while running a notebook
# - using the module fire to create a command line interface
# - directly test notebooks from the ipython's terminal capabilities

# %% [markdown]
# # Export

# %%
# !pip install fire
# Out:
# ...
#      |████████████████████████████████| 81kB 2.6MB/s
# ...
#   Created wheel for fire: filename=fire-0.2.1-py2.py3-none-any.whl size=103527 sha256=9f8a48c14af3add18ac363a0dbfce7041efc14b0ef528b411663399329cd7960
#   Stored in directory: /root/.cache/pip/wheels/31/9c/c0/07b6dc7faf1844bb4688f46b569efe6cafaa2179c95db821da
# Successfully built fire
# ...

# %%
import json

# %%
# !python notebook2script.py 00_exports.ipynb
# Out:
# Converted 00_exports.ipynb to exps/nb_00.py

# %%
import json

# %%
d =json.load(open('00_exports.ipynb','r'))['cells']

# %%
d[3]
# Out:
# {'cell_type': 'code',
#  'execution_count': 0,
#  'metadata': {'colab': {}, 'colab_type': 'code', 'id': 'af5aec2QjpZd'},
#  'outputs': [],
#  'source': ['#export \n', "TEST = 'test'"]}
